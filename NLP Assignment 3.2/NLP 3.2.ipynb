# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import spacy 
import en_core_web_sm
nlp = en_core_web_sm.load()
from nltk.tokenize import sent_tokenize 
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# #### Import data

# %%
reviews_df = pd.read_csv("reviews.csv")
reviews_df["noun_adj"] = ""
reviews_df = reviews_df[["reviews","noun_adj"]]
reviews_df.head()
# Out:
#                                              reviews noun_adj
# 0  Taking an Asian tour, we visited Singapore- wh...
# 1  We enjoyed our stay at 35th floor garden view!...
# 2  Room is spacious, clean and had a great view o...
# 3  We managed to time this just right as the sun ...
# 4  We stayed here for the access to the rooftop p...

# %% [markdown]
# #### Drop Empty rows

# %%
reviews_df['reviews'].replace('', np.nan, inplace=True)
reviews_df.dropna(subset=['reviews'], inplace=True)

# %% [markdown]
# #### Function to find the nearest noun
#
# To find the nearest noun from the input index

# %%
def nearest_noun(array, index):
    min_dist = 1000000
    min_index = None
    
    for i in range(len(array)):
        if array[i][1] in ('NOUN',"PROPN"):
            difference = abs(i-index)
            if difference <= min_dist:
                min_dist = difference
                min_index = i
                
    if min_index == None:
        return None
    else:
        return array[min_index][0]

# %% [markdown]
# #### Function to find the nearest adjective
#
# To find the nearest adjective from the input index

# %%
def nearest_adj(array, index):
    min_dist = 1000000
    min_index = None
    
    for i in range(index, len(array)):
        if array[i][1] == "ADJ":
            difference = abs(i-index)
            if difference <= min_dist:
                min_dist = difference
                min_index = i
                
    if min_index == None:
        return None
    else:
        return min_index

# %% [markdown]
# #### Function lemmatize the adjective-noun pairs
#
# To find the nearest adjective from the input index

# %%
def lemmatize_pairs(array):
    lemmatizer = WordNetLemmatizer() 
    result = []
    for pair in array:
        adj = ' '.join([lemmatizer.lemmatize(word, pos = 'a') for word in pair[0].split(' ')])
        noun = ' '.join([lemmatizer.lemmatize(word, pos = 'n') for word in pair[1].split(' ')])
        result.append((adj,noun))
    return result

# %%
def noun_adj(paragraph):
    sentences = sent_tokenize(paragraph) 
    noun_adj_pairs = []
    for sentence in sentences:
        
        #Initialise
        doc = nlp(sentence)
        noun = ''
        adj = ''
        pos_array = []
        
        # Create array of POS Tags
        for index,token in enumerate(doc): 
            pos_array.append((str(token).lower(),token.pos_))
            
        index = 0
        while index != len(pos_array):
            token = pos_array[index][0]
            tag = pos_array[index][1]
            
            # If the word at index is determiner, word at index+2 is noun 
            # and word at index+1 is not determiner or propernoun

            if tag == "DET" and index < len(pos_array)-2:
                if (pos_array[index+1][1] not in ("DET","PROPN")) and pos_array[index+2][1]=="NOUN":
                    adj = pos_array[index+1][0]
                    temp_noun = ''
                    temp_index = index+2
                    while temp_index != len(pos_array): # Chain the consecutive nouns
                        if pos_array[temp_index][1] == 'NOUN':
                            temp_noun = temp_noun + ' ' + pos_array[temp_index][0]
                            temp_index = temp_index + 1
                        else:
                            break
                    noun_adj_pairs.append((adj,temp_noun.strip()))
                    index = temp_index

                    #Check if an Aux follows a noun
                    if pos_array[index-1][1] == 'NOUN' and index < len(pos_array)-1:
                        if pos_array[index][1]=="AUX":
                            adj_index = nearest_adj(pos_array, index)
                            if adj_index: 
                                noun_adj_pairs.append((pos_array[adj_index][0],pos_array[index-1][0]))
                                if adj_index > index:
                                    index = adj_index + 1
                else:
                    index = index + 1
            
            # If there is an adjective tag
            elif tag == "ADJ":
                if index < len(pos_array)-1 and pos_array[index+1][0] == "to":
                    index = index + 1
                    
                elif index < len(pos_array)-1 and pos_array[index+1][1] == "NOUN":
                    adj = token
                    temp_noun = ''
                    temp_index = index+1
                    while temp_index != len(pos_array):
                        if pos_array[temp_index][1] == 'NOUN':
                            temp_noun = temp_noun + ' ' + pos_array[temp_index][0]
                            temp_index = temp_index + 1
                        else:
                            break
                    noun_adj_pairs.append((adj,temp_noun.strip()))
                    index = temp_index
                        
                else:
                    noun = nearest_noun(pos_array,index)
                    if noun and token:
                        noun_adj_pairs.append((token,noun))
                    index = index + 1
            else:
                index = index + 1
    return noun_adj_pairs

# %% [markdown]
# #### Get the noun adjective pairs of the reviews

# %%
total_pairs = []
for index,row in reviews_df.iterrows():
    paragraph = row["reviews"]
    noun_adj_pairs = noun_adj(paragraph)
    pairs = lemmatize_pairs(noun_adj_pairs)
    for pair in pairs:
        total_pairs.append(pair)
    reviews_df.loc[index]["noun_adj"] = pairs

# %% [markdown]
# #### Get the top count of the pairs

# %%
count_pairs = {}
for pair in total_pairs:
    if pair in count_pairs:
        count_pairs[pair] = count_pairs[pair] + 1
    else:
        count_pairs[pair] = 1

# %%
sorted_pairs = sorted(count_pairs.items(), key=lambda x: x[1], reverse=True)

# %%
print('{0:^3}{1:^50}{2:^15}'.format("","Pair","Count"))
index = 1
for pair in sorted_pairs:
    print('{0:^3}{1:^50}{2:^15}'.format(str(index),str(pair[0]),str(pair[1])))
    index = index + 1
# Out:
#                           Pair                            Count
#  1                ('spacious', 'room')                      3
#  2                 ('clean', 'room')                        3
#  3                ('rooftop', 'pool')                       3
#  4               ('incredible', 'view')                     2
#  5                 ('great', 'time')                        2
#  6                 ('nice', 'hotel')                        2
#  7                  ('good', 'view')                        2
#  8                  ('nice', 'room')                        2
#  9                 ('other', 'hotel')                       2
# 10              ('customer', 'service')                     2
# 11                 ('total', 'waste')                       2
# 12             ('master', 'access card')                    2
# 13               ('security', 'guard')                      2
# 14               ('incident', 'report')                     2
# 15                 ('asian', 'tour')                        1
# 16               ('incredible', 'top')                      1
# 17              ('firework', 'display')                     1
# 18                 ('hotel', 'room')                        1
# 19                  ('same', 'time')                        1
# 20                ('ringside', 'seat')                      1
# 21                 ('light', 'show')                        1
# 22           ('35th', 'floor garden view')                  1
# 23                 ('high', 'floor')                        1
# 24                 ('57th', 'floor')                        1
# 25             ('amazing', 'experience')                    1
# 26                 ('great', 'view')                        1
# 27                ('long', 'saturday')                      1
# 28                ('care', 'package')                       1
# 29                  ('mask', 'case')                        1
# 30               ('thoughtful', 'case')                     1
# 31                  ('sure', 'hand')                        1
# 32               ('left', 'hand side')                      1
# 33              ('viewing', 'platform')                     1
# 34               ('beautiful', 'view')                      1
# 35               ('wonderful', 'city')                      1
# 36               ('worth', 'entrance')                      1
# 37                ('entrance', 'fee')                       1
# 38                ('massive', 'hotel')                      1
# 39                ('worth', 'access')                       1
# 40                 ('many', 'option')                       1
# 41                ('good', 'location')                      1
# 42           ('different', 'tourist site')                  1
# 43                  ('big', 'room')                         1
# 44                  ('nice', 'view')                        1
# 45                ('awesome', 'view')                       1
# 46                  ('windy', 'pm')                         1
# 47                   ('cool', 'pm')                         1
# 48             ('complimentary', 'slice')                   1
# 49                 ('small', 'slice')                       1
# 50                 ('family', 'room')                       1
# 51                 ('room', 'fridge')                       1
# 52               ('pricey', 'minibar')                      1
# 53               ('great', 'location')                      1
# 54                 ('worth', 'pool')                        1
# 55                  ('many', 'hour')                        1
# 56                   ('hot', 'tub')                         1
# 57                ('popular', '-800')                       1
# 58                ('good', 'service')                       1
# 59          ('incredible', 'infinity pool')                 1
# 60             ('unforgettable', 'photo')                   1
# 61      ('outstanding', 'celebrity restaurant')             1
# 62                 ('modern', 'room')                       1
# 63              ('japanese', 'service')                     1
# 64                ('full', 'service')                       1
# 65               ('wish', 'tv system')                      1
# 66                  ('more', 'user')                        1
# 67                ('friendly', 'user')                      1
# 68             ('travel', 'restriction')                    1
# 69              ('spectacular', 'view')                     1
# 70                  ('twin', 'room')                        1
# 71              ('comfortable', 'girl')                     1
# 72                  ('big', 'girl')                         1
# 73                ('infinity', 'pool')                      1
# 74                ('crowded', 'pool')                       1
# 75                 ('worth', 'view')                        1
# 76            ('complimentary', 'parking')                  1
# 77               ('multiple', 'entry')                      1
# 78                ('local', 'tourist')                      1
# 79               ('beautiful', 'sand')                      1
# 80              ('glorious', 'country')                     1
# 81              ('great', 'experience')                     1
# 82            ('underwhelming', 'service')                  1
# 83               ('one', 'restaurant')                      1
# 84              ('available', 'booking')                    1
# 85               ('public', 'booking')                      1
# 86              ('other', 'restaurant')                     1
# 87                 ('lovely', 'room')                       1
# 88             ('beautiful', 'everytime')                   1
# 89                 ('staff', 'count')                       1
# 90                ('regular', 'count')                      1
# 91                 ('lovely', 'food')                       1
# 92               ('many', 'restaurant')                     1
# 93                  ('many', 'shop')                        1
# 94                 ('nice', 'thing')                        1
# 95                 ('lovely', 'bay')                        1
# 96              ('lovely', 'experience')                    1
# 97                  ('top', 'pool')                         1
# 98                 ('pool', 'usage')                        1
# 99                ('only', 'concern')                       1
# 100               ('tired', 'concern')                      1
# 101               ('general', 'couch')                      1
# 102              ('luxurious', 'room')                      1
# 103            ('perfect', 'opportunity')                   1
# 104                  ('5', 'star')                          1
# 105               ('average', 'hotel')                      1
# 106               ('little', 'thing')                       1
# 107                 ('open', 'desk')                        1
# 108               ('annoying', 'desk')                      1
# 109           ('iconic', 'infinity pool')                   1
# 110                 ('best', 'pool')                        1
# 111             ('inclement', 'weather')                    1
# 112               ('sun', 'umbrella')                       1
# 113              ('wet', 'everything')                      1
# 114               ('worth', 'bucket')                       1
# 115                ('bucket', 'list')                       1
# 116              ('early', 'february')                      1
# 117               ('good', 'product')                       1
# 118                ('human', 'touch')                       1
# 119               ('robotic', 'fact')                       1
# 120              ('top', 'class hotel')                     1
# 121               ('human', 'portion')                      1
# 122                ('happy', 'room')                        1
# 123                ('light', 'bulb')                        1
# 124             ('inconvenient', 'dark')                    1
# 125                ('unsafe', 'dark')                       1
# 126                ('senior', 'dark')                       1
# 127            ('disappointing', 'thing')                   1
# 128                ('other', 'room')                        1
# 129                ('comfy', 'room')                        1
# 130             ('expensive', 'opinion')                    1
# 131             ('temporary', 'access')                     1
# 132                ('upper', 'room')                        1
# 133               ('small', 'balcony')                      1
# 134            ('authentic', 'singapore')                   1
# 135               ('own', 'singapore')                      1
# 136                ('top', 'dollar')                        1
# 137              ('special', 'dollar')                      1
# 138               ('crowded', 'foyer')                      1
# 139                ('large', 'room')                        1
# 140               ('iconic', 'hotel')                       1
# 141                ('next', 'level')                        1
# 142               ('much', 'interest')                      1
# 143                 ('fine', 'room')                        1
# 144              ('excellent', 'view')                      1
# 145                ('hotel', 'lobby')                       1
# 146               ('tube', 'station')                       1
# 147               ('charged', 'price')                      1
# 148               ('more', 'privacy')                       1
# 149              ('symbolic', 'hotel')                      1
# 150              ('impressed', 'look')                      1
# 151               ('overall', 'look')                       1
# 152                 ('new', 'hotel')                        1
# 153              ('tired', 'interior')                      1
# 154                ('good', 'refurb')                       1
# 155                ('main', 'foyer')                        1
# 156               ('old', 'fashioned')                      1
# 157                 ('few', 'time')                         1
# 158                ('recent', 'stay')                       1
# 159                  ('8th', 'feb')                         1
# 160                 ('poor', 'bed')                         1
# 161                ('severe', 'ache')                       1
# 162            ('disappointed', 'night')                    1
# 163             ('good', 'night sleep')                     1
# 164                ('best', 'hotel')                        1
# 165                ('poor', 'sleep')                        1
# 166                 ('back', 'ache')                        1
# 167             ('premier', 'sky room')                     1
# 168                 ('big', 'size')                         1
# 169                ('little', 'size')                       1
# 170                 ('dull', 'size')                        1
# 171                 ('long', 'line')                        1
# 172             ('expensive', 'terrace')                    1
# 173        ('complete', 'diferent building')                1
# 174           ('spectacular', 'building')                   1
# 175              ('renowned', 'world')                      1
# 176              ('decent', 'service')                      1
# 177                ('front', 'desk')                        1
# 178                ('rude', 'bunch')                        1
# 179             ('particular', 'staff')                     1
# 180                ('night', 'shift')                       1
# 181               ('outdated', 'room')                      1
# 182                 ('old', 'room')                         1
# 183              ('rough', 'bathrobe')                      1
# 184               ('hard', 'bathrobe')                      1
# 185             ('uncomfortable', 'bed')                    1
# 186                 ('huge', 'room')                        1
# 187               ('poor', 'service')                       1
# 188                 ('other', 'day')                        1
# 189          ('disappointed', 'singapore')                  1
# 190                ('black', 'stain')                       1
# 191              ('removable', 'stain')                     1
# 192                ('full', 'month')                        1
# 193               ('such', 'service')                       1
# 194             ('atrocious', 'service')                    1
# 195           ('bad', 'hotel experience')                   1
# 196                ('hotel', 'guest')                       1
# 197            ('professional', 'hotel')                    1
# 198              ('own', 'hotel guest')                     1
# 199             ('embarrassed', 'wife')                     1
# 200               ('endless', 'check')                      1
# 201                ('famous', 'pool')                       1
# 202               ('maximum', 'hour')                       1
# 203                ('price', 'level')                       1
# 204             ('scary', 'experience')                     1
# 205                 ('d', 'couple')                         1
# 206                ('less', 'venue')                        1
# 207             ('bridal', 'suite room')                    1
# 208                 ('27th', 'may')                         1
# 209                ('suite', 'room')                        1
# 210                 ('door', 'bell')                        1
# 211              ('shocked', 'person')                      1
# 212                 ('mini', 'bar')                         1
# 213              ('real', 'intention')                      1
# 214             ('unknown', 'intruder')                     1
# 215               ('police', 'report')                      1
# 216              ('errible', 'spoiler')                     1
# 217            ('unfriendly', 'spoiler')                    1
# 218                ('first', 'place')                       1
# 219                ('more', '45mins')                       1
# 220              ('terrible', 'thing')                      1
# 221               ('family', 'member')                      1
# 222              ('sarcastic', 'staff')                     1
# 223                 ('room', 'door')                        1
# 224             ('difficult', '15mins')                     1
# 225                ('chinese', 'guy')                       1
# 226                  ('fast', 'wa')                         1
# 227            ('ridiculous', 'service')                    1
# 228             ('terrible', 'service')                     1
# 229              ('hotel', 'standard')                      1
# 230               ('kind', 'attitude')                      1
# 231                ('lovely', 'view')                       1
# 232             ('sensational', 'room')                     1
# 233              ('beautiful', 'suite')                     1
# 234              ('good', 'experience')                     1
# 235               ('gym', 'facility')                       1
# 236                 ('rude', 'duty')                        1
# 237               ('arrogant', 'duty')                      1
# 238               ('room', 'checkout')                      1
# 239                 ('few', 'hour')                         1
# 240              ('bad', 'experience')                      1
# 241            ('special', 'celebration')                   1
# 242             ('executive', 'lounge')                     1
# 243                 ('few', 'year')                         1
# 244              ('dirty', 'bathroom')                      1
# 245               ('bathroom', 'wall')                      1
# 246                ('pool', 'water')                        1
# 247                ('green', 'water')                       1
# 248              ('different', 'hotel')                     1
# 249                  ('male', 'mb')                         1
# 250                 ('key', 'card')                         1
# 251                 ('pool', 'area')                        1
# 252                ('scared', 'life')                       1
# 253            ('security', 'supervisor')                   1
# 254                ('first', 'thing')                       1
# 255               ('next', 'morning')                       1
# 256                ('phone', 'call')                        1
# 257           ('female', 'security staff')                  1
# 258              ('aware', 'incident')                      1
# 259          ('traumatizing', 'experience')                 1
# 260                 ('sure', 'rest')                        1
# 261               ('pleasant', 'stay')                      1
# 262                 ('sure', 'job')                         1
# 263               ('best', 'interest')                      1
# 264                 ('sure', 'mind')                        1
# 265              ('security', 'staff')                      1
# 266              ('different', 'staff')                     1
# 267                ('other', 'name')                        1
# 268                 ('name', 'tag')                         1
# 269              ('numerous', 'hotel')                      1
# 270              ('luxurious', 'hotel')                     1
# 271               ('5-star', 'hotel')                       1
# 272               ('1-star', 'hotel')                       1
# 273              ('money', 'someplace')                     1
# 274             ('oppressive', 'place')                     1
# 275                ('cold', 'place')                        1
# 276              ('inviting', 'resort')                     1
# 277            ('interested', 'company')                    1
# 278            ('quarterly', 'earnings')                    1
# 279              ('right', 'customer')                      1
# 280            ('local', 'cable company')                   1
# 281              ('stellar', 'company')                     1
# 282                 ('blind', 'eye')                        1

# %%
reviews_df.head()
# Out:
#                                              reviews  \
# 0  Taking an Asian tour, we visited Singapore- wh...
# 1  We enjoyed our stay at 35th floor garden view!...
# 2  Room is spacious, clean and had a great view o...
# 3  We managed to time this just right as the sun ...
# 4  We stayed here for the access to the rooftop p...
#
#                                             noun_adj
# 0  [(asian, tour), (incredible, view), (incredibl...
# 1  [(35th, floor garden view), (high, floor), (gr...
# 2  [(spacious, room), (clean, room), (great, view...
# 3  [(sure, hand), (left, hand side), (viewing, pl...
# 4  [(rooftop, pool), (massive, hotel), (worth, ac...

# %% [markdown]
# #### Save to csv file

# %%
reviews_df.to_csv("reviews_spacy.csv",index=False)

# %% [markdown]
# ### Test the program
#
#  Run the cell below
#
#  example input: This room is great. The view is beautiful.

# %%
#run this your text here
paragraph = input("Enter your paragraph: ")
print("="*50)
print("Extracted (adjective noun) pairs below:")
print(noun_adj(paragraph))
# Out:
# Enter your paragraph: This room is great. The view is beautiful
# ==================================================
# Extracted (adjective noun) pairs below:
# [('great', 'room'), ('beautiful', 'view')]
